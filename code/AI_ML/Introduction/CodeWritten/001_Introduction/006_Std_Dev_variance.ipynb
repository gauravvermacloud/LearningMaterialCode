# %%
import numpy as np
import matplotlib.pyplot as plt

spendings = np.random.normal(100.0, 20.0, 10000)

plt.hist(spendings, 50)
plt.show()

# %%
spendings
# Out:
# array([ 77.52247688,  79.29728678,  81.52893025, ..., 119.4632237 ,
#        122.42888471,  62.80831213])

# %%
l = list(spendings)
l
# Out:
# [77.52247687664521,
#  79.29728677905169,
#  81.52893024836942,
#  148.55282114663714,
#  106.84311685260582,
#  31.60115340707138,
#  129.13427092856512,
#  157.4872965311772,
#  106.30236537162129,
#  108.05984923555677,
#  95.01246862227829,
#  106.8570054763573,
#  158.86185742189596,
#  97.98263620621566,
#  108.50977150648485,
#  75.85699440345051,
#  90.24653893825683,
#  102.38824449514492,
#  99.57291094553719,
#  92.75871695844708,
#  110.45412642645765,
#  106.65826053721054,
#  136.08580051593984,
#  106.93880914562773,
#  113.9586094858243,
#  64.01993047735601,
#  81.2442733098603,
#  104.51798744358476,
#  111.74770871435933,
#  76.44672575628339,
#  138.06554680617396,
#  108.42206757599537,
#  90.34293790301926,
#  90.82004589974282,
#  91.96710182989497,
#  63.627175339595475,
#  81.41972521950348,
#  58.00870534662187,
#  109.3444478023687,
#  102.0210315681907,
#  118.94854460546927,
#  72.34061370020524,
#  64.74848982982721,
#  103.97345230188418,
# ...

# %%
variance = np.var(l)
variance
# Out:
# 403.32067990860133

# %%
std = np.std(l)
std
# Out:
# 20.082845413650958
